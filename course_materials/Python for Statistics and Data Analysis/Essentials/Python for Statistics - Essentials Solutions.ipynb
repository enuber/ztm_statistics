# %% [markdown]
# # Print Function

# %%
# Simple print example
print("Hello, World!")
# Out:
# Hello, World!

# %%
#Without print function
print("Hello")
print("World")
# Out:
# Hello
# World

# %%
# Print with Inputs using commas
name = "Diogo"
age = 31
print("My name is", name,"and I am", age, "years old")
# Out:
# My name is Diogo and I am 31 years old

# %%
# String concatenation (+)
print("My name is " + name + " and I am " + str(age) +" years old")
# Out:
# My name is Diogo and I am 31 years old

# %%
# F-string
print(f"My name is {name} and I am {age} years old")
# Out:
# My name is Diogo and I am 31 years old

# %% [markdown]
# # Input Function

# %%
#Input function
name = input()

# %%
#Customizable Input Function
name = input("Please enter your name: ")
# Out:
# Please enter your name: Diogo

# %%
#Personalized Greeting
name = input("Please enter your name: ")
age = int(input("Please enter your age: "))

#Print function to greet
print(f"Hello, {name}! You are {age} years old")
# Out:
# Please enter your name: Diogo
# Please enter your age: 31
# Hello, Diogo! You are 31 years old

# %% [markdown]
# # Challenge: Create Superhero name

# %%
# Step 1: find the adjective on the 13th page of the book
adjective = input("Find first adjective in the 13th page of a book: ")
#My dalmatian cookbook -> finely

# Step 2: something that scares you (noun)
noun = input("Something that scares you: ")

# Step 3: display the information to the user
print(f"You superhero name is {adjective} {noun}")
# Out:
# Find first adjective in the 13th page of a book: Finely
# Something that scares you: Finamzamt
# You superhero name is Finely Finamzamt

# %% [markdown]
# # Variable Types in Python

# %%
# Checking Variable Type
name = "Diogo"
age = 31
height = 1.83
print(type(name))
print(type(age))
print(type(height))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
# Transorm a float into an integer
height = 1.83
height_integer = int(height)
print(height)
print(height_integer)
# Out:
# 1.83
# 1

# %%
# Transform a integer into a float
a = 1
b = float(a)
print(a)
print(b)
# Out:
# 1
# 1.0

# %%
# Transform a stringo into a float / integer
height = float(input("Please insert your height: "))
type(height)
# Out:
# Please insert your height: 1.83
# float

# %%
# Boolean
c = True
type(c)
# Out:
# bool

# %% [markdown]
# # Arithmetic Operators

# %%
# Declaring Variables
x = 5
y = 3

# %%
#Addition
result = x + y
print(result)
# Out:
# 8

# %%
# Subtrations
x - y
# Out:
# 2

# %%
# Multiplication
x * y
# Out:
# 15

# %%
# Division
x / y
# Out:
# 1.6666666666666667

# %%
# Modulus
x % y
# Out:
# 2

# %%
# Exponential
x ** y
# Out:
# 125

# %%
# Floor Division
x // y
# Out:
# 1

# %%
# Compound Assignment operators ( +=, -=, *=, /=, %=, **=, //=)
x += 3 # equivalent to x = x + 3
print(x)
# Out:
# 8

# %%
# Less techie way of doing it
x = x + 3
print(x)
# Out:
# 11

# %%
# floor division compound
x //= 5
print(x)
# Out:
# 2

# %% [markdown]
# # Python Comparison Operators

# %%
# Declaring the variables
x = 5
y = 3

# %%
# Equal to (==)
x == y
# Out:
# False

# %%
# Not equal
x != y
# Out:
# True

# %%
# Greater than (>) 
x > y
# Out:
# True

# %%
# Less than
x < y
# Out:
# False

# %%
# Greater than or equal to
x >= y
# Out:
# True

# %%
# Less than or equal to (<=)
x <= y
# Out:
# False

# %% [markdown]
# # Challenge Solutions

# %%
# Step 1 - Prompt the user for the meal cost
meal_cost = float(input("Enter the total cost of the meal: "))

# Step 2 - Prompt the user for the tip percentage
tip_percentage = float(input("Enter the tip percentage desired (e.g., 15 for 15%): "))

# Step 3 - Prompt the user for the number of people at the table
number_of_people = int(input("Enter the number of people at the table: "))

# Step 4 - Calculate the tip amount using the tip percentage and the meal cost
tip_amount = meal_cost * (tip_percentage / 100)

# Step 5 - Calculate the total cost of the meal, including the tip
total_cost = meal_cost + tip_amount

# Step 6 - Calculate the average cost per person
cost_per_person = total_cost / number_of_people

# Step 7 - Display everything to users: tip amount, total cost, cost per person
print(f"Tip amount: ${tip_amount:.2f}")
print(f"Total cost: ${total_cost:.2f}")
print(f"Cost per person: ${cost_per_person:.2f}")
# Out:
# Enter the total cost of the meal: 12
# Enter the tip percentage desired (e.g., 15 for 15%): 20
# Enter the number of people at the table: 2
# Tip amount: $2.40
# Total cost: $14.40
# Cost per person: $7.20

# %% [markdown]
# #If-else conditions

# %%
#If statement
x = 2

if x > 5:
  print("X is greater than 5")

# %%
#If statement part 2
x = 10

if x > 5:
  print("X is greater than 5")
# Out:
# X is greater than 5

# %%
#If + elif
x = 20

#if condition
if x > 15:
  print("x is greater than 15")
elif x > 5:
  print("x is greater than 5 but not greater than 15")
# Out:
# x is greater than 15

# %%
# if + elif + else
x = -10

#if condition
if x > 15:
  print("x is greater than 15")
elif x > 5:
  print("x is greater than 5 but not greater than 15")
else:
  print("x is less than or equal to 5")
# Out:
# x is less than or equal to 5

# %% [markdown]
# # Exercise: Can you vote?

# %%
# Create a if-else condition that tells you whether they can vote
# The assessment must be based on their age

age = int(input("Please enter your age: "))

#if-else condition
if age >= 18:
  print("You are eligible to vote.")
else:
  print("You are not eligible to vote")
# Out:
# Please enter your age: 12
# You are not eligible to vote

# %% [markdown]
# # Exercise: Grading Papers

# %%
# Take an input of a test score (0-100) and transform it into a grade (A-F)
score = float(input("Enter your score (0-100): "))

if score >= 90:
  grade = 'A'
elif score >= 80:
  grade = 'B'
elif score >= 70:
  grade = 'C'
elif score >= 60:
  grade = 'D'
else:
  grade = 'F'
print(f"Your score of {score} is equivalent to a {grade} grade")
# Out:
# Enter your score (0-100): 50
# Your score of 50.0 is equivalent to a F grade

# %% [markdown]
# #Challenge - Berghain Club Bouncer

# %%
# Step 1: Get user's age and the current number of guests
age = int(input("Please tell me you age: "))
current_guests = int(input("Enter current number of people in the club: "))

# Step 2: Current Entry rules
min_age = 18
max_age = 60
max_guests = 200

# Step 3: Use comparisons to determine if a guest can enter
can_enter = (min_age <= age <= max_age) and (current_guests < max_guests)

# Step 4: Communicate to user if he or she can enter
if can_enter:
  print("Welcome to Berghain and have fun")
elif age < min_age or age > max_age:
  print("Sorry, you cannot enter the club due to your age")
elif current_guests > max_guests:
  print("Sorry, the club is at max capacity")
else:
  print("Sorry, not tonight")
# Out:
# Please tell me you age: 14
# Enter current number of people in the club: 150
# Sorry, you cannot enter the club due to your age

# %% [markdown]
# # Challenge: Your Monthly Savings Plan

# %%
# Step 1 - Prompt the user for their age
current_age = int(input("Please enter your current age: "))

# Step 2 - Prompt for desired retirement age
retirement_age = int(input("Please enter your target retirement age: "))

#Step 3 - Prompt for desired savings when retired
desired_savings = float(input("Enter your desired retirement savings: "))

#step 4 - Prompt for interest rate
interest_rate = float(input("Enter annual interest rate in your savings (e.g., 5 for 5%): "))

#Step 5 - numbers of years until retirements
years_until_retirement = retirement_age - current_age
print(f"You have {years_until_retirement} left to work")

# Step 6- calculate number of months until retirement
months_until_retirement = years_until_retirement * 12

#Step 7 - Calculate monthly interest rate
monthly_interest_rate = (1 + interest_rate / 100) ** (1/12) - 1

#Step 8 - Determine the monthly savings
monthly_savings = (desired_savings * monthly_interest_rate
                   ) / ((1 + monthly_interest_rate) ** months_until_retirement -1)

#Step  9 - communicate the ideal monthly savings to the user
print(f"Ideal monthly savings amount: {monthly_savings:.0f}")
# Out:
# Please enter your current age: 31
# Please enter your target retirement age: 70
# Enter your desired retirement savings: 2000000
# Enter annual interest rate in your savings (e.g., 5 for 5%): 8
# You have 39 left to work
# Ideal monthly savings amount: 673.2

# %%
#Example -> 10% interest rate
monthly_interest_rate = (1+0.1) ** (1/12) -1
print(monthly_interest_rate)
# Out:
# 0.007974140428903764
